# %% [markdown]
# ### Install searchtweets library

# %%
import csvkit
import requests
import os
import json
import pandas as pd

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FullArchiveSearchPython"
    return r

# %%
def connect_to_endpoint(url, params):
    response = requests.request("GET", search_url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def main():
    json_response = connect_to_endpoint(search_url, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True, ensure_ascii=False))

# %%
bearer_token =                                                           'AAAAAAAAAAAAAAAAAAAAAB0BUgEAAAAAFP%2FBMfx6jCiTJE%2FEvHgt9C9Jnm4%3DeIXDOLSo5gH9gIls4YWpF25sW52LxqDpxvk29lMN6kZYtkkzPD'

# %%
headers = {"Authorization": "Bearer {}".format(bearer_token)}

# %%
search_url = "https://api.twitter.com/2/tweets/search/recent"

# %%
query_params = {'query':'(asian hate crime OR racism OR BLM) -is:retweet -is:reply',
                'expansions':'author_id',
                'place.fields':'contained_within,country,country_code,full_name,geo,id,name,place_type',
                'tweet.fields':'geo',
                'user.fields':'location',
                'max_results':100
               }

# %%
if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "1031917752330670080",
#             "id": "1446702074587230209",
#             "text": "Bullying is classificatively racist.\n\nSuperhuman racism = identificatively racist.  Argument of free will.  That is 1 upping.  For sport.  \n\nNot same category.\n\nDifference, you benefit somehow.  That is trade warfare."
#         },
#         {
#             "author_id": "1404440303314956288",
#             "id": "1446702030530048004",
#             "text": "kenapa pc gue blm dikirim juga dari 25.9"
#         },
#         {
#             "author_id": "774004690774286336",
#             "id": "1446702016215007234",
#             "text": "I never thought Alessandra was even racist. I only thought she wanted to avoid loud rude people one time. like provocative rap for example that was popular at the time. but not actual racism."
#         },
#         {
#             "author_id": "21796027",
# ...

# %%
json_response = connect_to_endpoint(search_url, query_params)
# Out:
# 200

# %%
response = requests.request("GET", search_url, headers=headers,
                            params=query_params).json()

# %%
df = pd.DataFrame(response['data'])
df.to_csv('tweets.csv')

# %%
df = pd.DataFrame(response['includes'])
df.to_csv('user.csv')
